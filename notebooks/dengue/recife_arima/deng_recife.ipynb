# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
module_path = os.path.abspath(os.path.join('..', '..', '..', 'src'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler
from Preprocessing import df_transforming
# Out:
# c:\Users\Talita\OneDrive\Documentos\MultiLSTM-ARB\src\Preprocessing.py:6: SyntaxWarning: invalid escape sequence '\d'
#   df['NU_IDADE_N'] = df['NU_IDADE_N'].str.extract('(\d+)').astype(int)

# %%
FILEPATH = '../../../data/dengue_recife.parquet'

# %%
df = pd.read_parquet(FILEPATH)
df
# Out:
#          DT_NOTIFIC SEM_NOT NU_ANO DT_SIN_PRI NU_IDADE_N CS_SEXO CS_RACA  \
# 60002    2015-11-19  201546   2015 2015-10-20  73 ano(s)       F       9
# 60006    2015-12-04  201548   2015 2015-12-04  28 ano(s)       M       9
# 60008    2015-12-10  201549   2015 2015-12-07  29 ano(s)       F       9
# 60011    2015-12-17  201550   2015 2015-12-09  40 ano(s)       M       9
# 60013    2015-12-18  201550   2015 2015-12-18  53 ano(s)       M       9
# ...             ...     ...    ...        ...        ...     ...     ...
# 13340458 2023-03-31  202313   2023 2023-03-31   7 ano(s)       M       4
# 13340459 2023-03-31  202313   2023 2023-03-10   7 ano(s)       F       9
# 13340460 2023-03-31  202313   2023 2023-03-25  39 ano(s)       F       9
# 13340462 2023-03-31  202313   2023 2023-03-29   7 ano(s)       M       9
# 13340472 2023-03-31  202313   2023 2023-03-30  34 ano(s)       M       2
#
#          ID_MUNICIP CS_GESTANT CS_ESCOL_N  ... CEFALEIA EXANTEMA VOMITO  \
# 60002        Recife          6         9   ...        3        3      3
# 60006        Recife          6         9   ...        3        3      3
# 60008        Recife          9         9   ...        3        3      3
# 60011        Recife          6         9   ...        3        3      3
# 60013        Recife          6          9  ...        3        3      3
# ...             ...        ...        ...  ...      ...      ...    ...
# 13340458     Recife          6         10  ...        2        2      2
# 13340459     Recife          6         10  ...        2        2      2
# 13340460     Recife          9         9   ...        1        2      2
# 13340462     Recife          6         10  ...        2        2      2
# 13340472     Recife          6         9   ...        2        2      2
#
#          NAUSEA DOR_COSTAS CONJUNTVIT HOSPITALIZ CLASSI_FIN EVOLUCAO DT_OBITO
# 60002         3          3          3          2         10        1     None
# 60006         3          3          3          2         10        1     None
# 60008         3          3          3          2         10        1     None
# 60011         3          3          3          9         10        1     None
# 60013         3          3          3          9         8         9     None
# ...         ...        ...        ...        ...        ...      ...      ...
# 13340458      2          2          2          9         10        1     None
# 13340459      1          2          2          2         10        1     None
# 13340460      2          1          2          2         10        1     None
# 13340462      2          2          2          2         10        1     None
# 13340472      2          2          2          9         8         9     None
#
# [78400 rows x 22 columns]

# %%
df = df_transforming(df)
df
# Out:
#       POPULACAO  NUM_CASOS_SEM  TAXA_INC_SEM  NUM_CASOS_MES  TAXA_INC_MES  \
# 0       1633697             34      2.081169            181     11.079166
# 1       1633697             34      2.081169            181     11.079166
# 2       1633697             34      2.081169            181     11.079166
# 3       1633697             34      2.081169            181     11.079166
# 4       1633697             34      2.081169            181     11.079166
# ...         ...            ...           ...            ...           ...
# 2187    1568854             38      2.422150            189     12.047010
# 2188    1568854             38      2.422150            189     12.047010
# 2189    1568854             38      2.422150            189     12.047010
# 2190    1568854             38      2.422150            189     12.047010
# 2191    1568854             38      2.422150            189     12.047010
#
#      DT_NOTIFIC  NUM_CASOS_DIARIOS
# 0    2017-01-02                 10
# 1    2017-01-03                 14
# 2    2017-01-04                  3
# 3    2017-01-05                  4
# 4    2017-01-06                  1
# ...         ...                ...
# 2187 2023-12-25                  1
# 2188 2023-12-26                 19
# 2189 2023-12-27                 11
# 2190 2023-12-28                  5
# 2191 2023-12-30                  2
#
# [2192 rows x 7 columns]
